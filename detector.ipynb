# %%
import csv
import re
from collections import Counter

# %%
# Define input and output filenames
input_filename = "../data/sso_posts.csv"
output_filename = "../data/pytorch_posts.csv"
results_filename = "../results/pytorch_results.csv"

# %%
# Define regex pattern to match "pytorch" in title, body or tags
pattern = re.compile(r"pytorch", re.IGNORECASE)

# Initialize counters for number of posts and keywords
num_posts = 0
keyword_counter = Counter()

# %%
# Open input and output files
with open(input_filename, "r", encoding="utf-8") as input_file, \
        open(output_filename, "w", encoding="utf-8", newline="") as output_file:

    # Create CSV reader and writer objects
    input_reader = csv.DictReader(input_file)
    output_writer = csv.DictWriter(output_file, fieldnames=input_reader.fieldnames)

    # Write header row to output file
    output_writer.writeheader()

    # Loop through each row in input file
    for row in input_reader:

        # Check if row contains "pytorch" in title, body or tags
        if any(pattern.search(row[field]) for field in ["Title", "Body", "Tags"]):

            # Increment post count
            num_posts += 1

            # Extract keywords from tags field and update keyword counter
            tags = row["Tags"].strip("<>").split("><")
            keywords = [tag for tag in tags if pattern.search(tag)]
            keyword_counter.update(keywords)

            # Write row to output file
            output_writer.writerow(row)

# %%
# Sort keyword counter by count in descending order
sorted_keywords = sorted(keyword_counter.items(), key=lambda x: x[1], reverse=True)

# %%
# Open results file and write number of posts and top 10 keywords
with open(results_filename, "w", encoding="utf-8", newline="") as results_file:
    results_writer = csv.writer(results_file)
    results_writer.writerow(["Number of posts:", num_posts])
    results_writer.writerow(["Top keywords:"])
    for keyword, count in sorted_keywords[:10]:
        results_writer.writerow([keyword, count])

# %%
import pandas as pd

# %%
# Load and preprocess the data
data = pd.read_csv('../data/cleaned_pytorch_posts.csv')
data.sample(10)
# Out:
#              Id  PostTypeId  ParentId
# 6643   61451339           1       NaN  \
# 16705  71083080           1       NaN
# 6546   61318213           1       NaN
# 11027  66051641           1       NaN
# 11911  66921943           1       NaN
# 12967  67869267           1       NaN
# 9072   63991646           1       NaN
# 5277   59581762           1       NaN
# 2835   55648989           1       NaN
# 13623  68425009           1       NaN
#
#                                                    Title
# 6643   PyTorch LSTM crashing on colab gpu works fine ...  \
# 16705  registering a hook with pytorch does not chang...
# 6546   From Coco annotation json to semantic segmenta...
# 11027  How to create a submodel from a pretrained mod...
# 11911  PyTorch Tensor Operation for adding the maximu...
# 12967  Subset object is not an iterator for updating ...
# 9072   How to find the mean and the covariance of a 2...
# 5277        install import Pytorch on mac osx python 3 7
# 2835    How to make pycharm use a different cuda toolkit
# 13623        One Hot Encoding in Pytorch for two classes
#
#                                                     Body  Score
# 6643   Hello I have following LSTM which runs fine on...      1  \
# 16705  I m trying to remove nans infs from a gradient...      1
# 6546   I am trying to use COCO 2014 data for semantic...      1
# 11027  So I have been working on neural style transfe...      1
# 11911  Follow Up question to Basically adding the max...      1
# 12967  I m updating a pytorch network from legacy cod...      1
# 9072   I have a tensor of shape h w which consists of...      0
# 5277   I have torch all installed in a virtual env bu...      2
# 2835   I want to run an MXNet module in GPU I have a ...      0
# 13623  I have a tensor of 0 and 1 which I calculated ...      0
#
#                                                     Tags  ViewCount
# 6643                pytorch gpu lstm google-colaboratory      594.0  \
# 16705                        python pytorch gradient nan      120.0
# 6546                  pytorch semantic-segmentation coco     3389.0
# 11027  machine-learning pytorch pre-trained-model sty...     1148.0
# 11911          python pytorch dynamic-programming tensor      115.0
# 12967                    pytorch sentiment-analysis imdb      265.0
# 9072                pytorch mean distribution covariance      111.0
# 5277                       pip pytorch python-3.7 parlai      221.0
# 2835                                python pycharm mxnet     1162.0
# 13623                    python pytorch one-hot-encoding      800.0
#
#        FavoriteCount
# 6643             NaN
# 16705            NaN
# 6546             NaN
# 11027            NaN
# 11911            NaN
# 12967            NaN
# 9072             NaN
# 5277             NaN
# 2835             NaN
# 13623            NaN
